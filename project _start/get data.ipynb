# %%
import pandas as pd
d=pd.read_excel("final nan.xlsx")
d
# Out:
#       Unnamed: 0  S.No        District         Year  Season          Crop  \
# 0              0     1        Adilabad  2014 - 2015  Kharif  cotton(lint)
# 1              1     2        Adilabad  2015 - 2016  Kharif  cotton(lint)
# 2              2     3        Adilabad  2016 - 2017  Kharif  cotton(lint)
# 3              3     4        Adilabad  2017 - 2018  Kharif  cotton(lint)
# 4              4     5        Adilabad  2018 - 2019  Kharif  cotton(lint)
# ...          ...   ...             ...          ...     ...           ...
# 1115        1131  1132  Warangal urban  2019 - 2020    rabi          Rice
# 1116        1132  1133         Yadadri  2016 - 2017    rabi          Rice
# 1117        1133  1134         Yadadri  2017 - 2018    rabi          Rice
# 1118        1134  1135         Yadadri  2018 - 2019    rabi          Rice
# 1119        1135  1136         Yadadri  2019 - 2020    rabi          Rice
#
#       Rainfall(mm)  Minimum Temparature(C)  Maximum Temperature (C)    Ph  \
# ...

# %%
d.columns
# Out:
# Index(['Unnamed: 0', 'S.No', 'District', 'Year', 'Season', 'Crop',
#        'Rainfall(mm)', 'Minimum Temparature(C)', 'Maximum Temperature (C)',
#        'Ph', 'N(Kg/Hectar)', 'P(Kg/Hectar)', 'K(Kg/Hectar)', 'Zn(ppm)',
#        'Fe(ppm)', 'Cu(ppm)', 'Mn(ppm)', 'Irrigation(MBGL)',
#        'Yield (Bales/Hectare)'],
#       dtype='object')

# %%
d['Season'].unique()
# Out:
# array(['Kharif', 'rabi'], dtype=object)

# %%
import datetime
current_date = datetime.date.today()
if current_date.month >= 6 and current_date.month <= 10:
    Season = 'Kharif'
else:
    Season = 'rabi'

district=input("Select district")
data = d[(d['District'] == district) & (d['Season'] == Season)]
data
# Out:
# Select districtAdilabad
#      Unnamed: 0  S.No  District         Year  Season               Crop  \
# 0             0     1  Adilabad  2014 - 2015  Kharif       cotton(lint)
# 1             1     2  Adilabad  2015 - 2016  Kharif       cotton(lint)
# 2             2     3  Adilabad  2016 - 2017  Kharif       cotton(lint)
# 3             3     4  Adilabad  2017 - 2018  Kharif       cotton(lint)
# 4             4     5  Adilabad  2018 - 2019  Kharif       cotton(lint)
# 5             5     6  Adilabad  2019 - 2020  Kharif       cotton(lint)
# 142         142   143  Adilabad  2014 - 2015  Kharif              Maize
# 143         143   144  Adilabad  2015 - 2016  Kharif              Maize
# 144         144   145  Adilabad  2016 - 2017  Kharif              Maize
# 145         145   146  Adilabad  2017 - 2018  Kharif              Maize
# 146         146   147  Adilabad  2018 - 2019  Kharif              Maize
# 147         147   148  Adilabad  2019 - 2020  Kharif              Maize
# ...

# %%
avg_rainfall=data['Rainfall(mm)'].mean()
avg_min_temp=data['Minimum Temparature(C)'].mean()
avg_max_temp=data['Maximum Temperature (C)'].mean()
print("avg_rainfall:",avg_rainfall)
print("avg_min_temp:",avg_min_temp)
print("avg_max_temp:",avg_max_temp)
# Out:
# avg_rainfall: 200.52666666666664
# avg_min_temp: 25.38
# avg_max_temp: 39.94

# %%
a=d.groupby(['District', 'Season',])[['Rainfall(mm)','Minimum Temparature(C)','Maximum Temperature (C)']].mean()
a
# Out:
#                        Rainfall(mm)  Minimum Temparature(C)  \
# District       Season
# Adilabad       Kharif    200.526667               25.380000
#                rabi       12.616667               22.300000
# Bhadradri      Kharif    218.820000               25.800000
#                rabi       12.796429               22.033333
# Jagitial       Kharif    188.360000               24.600000
# ...                             ...                     ...
# Warangal       rabi       14.444522               23.660000
# Warangal urban Kharif    201.565000               25.666667
#                rabi       10.371440               19.566667
# Yadadri        Kharif    129.080000               24.866667
#                rabi        8.575000               20.166667
#
#                        Maximum Temperature (C)
# District       Season
# Adilabad       Kharif                39.940000
#                rabi                  42.220000
# Bhadradri      Kharif                40.033333
# ...
