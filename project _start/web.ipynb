# %%
import pandas as pd
d=pd.read_excel("final catgry.xlsx")
d
# Out:
#       Unnamed: 0.1  Unnamed: 0  S.No  Rainfall(mm)  Minimum Temparature(C)  \
# 0                0           0     1    156.040000               29.100000
# 1                1           1     2    165.740000               26.100000
# 2                2           2     3    240.520000               27.300000
# 3                3           3     4    180.180000               27.600000
# 4                4           4     5    256.060000               25.380000
# ...            ...         ...   ...           ...                     ...
# 1115          1115        1131  1132     15.042900                9.600000
# 1116          1116        1132  1133      5.171429               28.300000
# 1117          1117        1133  1134     11.285714               20.000000
# 1118          1118        1134  1135      6.571429               20.166667
# 1119          1119        1135  1136     11.271429               12.200000
#
# ...

# %%
d.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'S.No', 'Rainfall(mm)',
#        'Minimum Temparature(C)', 'Maximum Temperature (C)', 'Ph',
#        'N(Kg/Hectar)', 'P(Kg/Hectar)', 'K(Kg/Hectar)', 'Zn(ppm)', 'Fe(ppm)',
#        'Cu(ppm)', 'Mn(ppm)', 'Irrigation(MBGL)', 'Yield (Bales/Hectare)',
#        'District_Adilabad', 'District_Bhadradri', 'District_Jagitial',
#        'District_Jangoan', 'District_Jayashankar', 'District_Jogulamba',
#        'District_Kamareddy', 'District_Karimnagar', 'District_Khammam',
#        'District_Komaram bheem asifabad', 'District_Mahabubabad',
#        'District_Mahbubnagar', 'District_Mancherial', 'District_Medak',
#        'District_Medchal', 'District_Mulugu', 'District_Nagarkurnool',
#        'District_Nalgonda', 'District_Narayanapet', 'District_Nirmal',
#        'District_Nizamabad', 'District_Peddapalli', 'District_Rajanna',
#        'District_Rangareddy', 'District_Sangareddy', 'District_Siddipet',
# ...

# %%
for i in d.columns:
    if (i[:4]=="Crop"):
        print("<option value="+'"'+i+'">'+i[4:]+"</option>")
# Out:
# <option value="Crop_Groundnut">_Groundnut</option>
# <option value="Crop_Maize">_Maize</option>
# <option value="Crop_Moong(Green Gram)">_Moong(Green Gram)</option>
# <option value="Crop_Rice">_Rice</option>
# <option value="Crop_cotton(lint)">_cotton(lint)</option>

# %%
for i in d.columns:
    if (i[:6]=="Season"):
        print("<option value="+'"'+i+'">'+i[7:]+"</option>")
# Out:
# <option value="Season_Kharif">Kharif</option>
# <option value="Season_rabi">rabi</option>

# %%
for i in d.columns:
    if (i[:8]=="District"):
        print("<option value="+'"'+i[9:]+'">'+i[9:]+"</option>")
# Out:
# <option value="Adilabad">Adilabad</option>
# <option value="Bhadradri">Bhadradri</option>
# <option value="Jagitial">Jagitial</option>
# <option value="Jangoan">Jangoan</option>
# <option value="Jayashankar">Jayashankar</option>
# <option value="Jogulamba">Jogulamba</option>
# <option value="Kamareddy">Kamareddy</option>
# <option value="Karimnagar">Karimnagar</option>
# <option value="Khammam">Khammam</option>
# <option value="Komaram bheem asifabad">Komaram bheem asifabad</option>
# <option value="Mahabubabad">Mahabubabad</option>
# <option value="Mahbubnagar">Mahbubnagar</option>
# <option value="Mancherial">Mancherial</option>
# <option value="Medak">Medak</option>
# <option value="Medchal">Medchal</option>
# <option value="Mulugu">Mulugu</option>
# <option value="Nagarkurnool">Nagarkurnool</option>
# <option value="Nalgonda">Nalgonda</option>
# <option value="Narayanapet">Narayanapet</option>
# <option value="Nirmal">Nirmal</option>
# ...

# %%
d
# Out:
#       Unnamed: 0.1  Unnamed: 0  S.No  Rainfall(mm)  Minimum Temparature(C)  \
# 0                0           0     1    156.040000               29.100000
# 1                1           1     2    165.740000               26.100000
# 2                2           2     3    240.520000               27.300000
# 3                3           3     4    180.180000               27.600000
# 4                4           4     5    256.060000               25.380000
# ...            ...         ...   ...           ...                     ...
# 1115          1115        1131  1132     15.042900                9.600000
# 1116          1116        1132  1133      5.171429               28.300000
# 1117          1117        1133  1134     11.285714               20.000000
# 1118          1118        1134  1135      6.571429               20.166667
# 1119          1119        1135  1136     11.271429               12.200000
#
# ...
