# %%
import pandas as pd
import numpy as np
df=pd.read_excel("final1.xlsx")
df
# Out:
#       S.No        District         Year  Season          Crop  Rainfall(mm)  \
# 0        1        Adilabad  2014 - 2015  Kharif  cotton(lint)    156.040000
# 1        2        Adilabad  2015 - 2016  Kharif  cotton(lint)    165.740000
# 2        3        Adilabad  2016 - 2017  Kharif  cotton(lint)    240.520000
# 3        4        Adilabad  2017 - 2018  Kharif  cotton(lint)    180.180000
# 4        5        Adilabad  2018 - 2019  Kharif  cotton(lint)    256.060000
# ...    ...             ...          ...     ...           ...           ...
# 1131  1132  Warangal urban  2019 - 2020    rabi          Rice     15.042900
# 1132  1133         Yadadri  2016 - 2017    rabi          Rice      5.171429
# 1133  1134         Yadadri  2017 - 2018    rabi          Rice     11.285714
# 1134  1135         Yadadri  2018 - 2019    rabi          Rice      6.571429
# 1135  1136         Yadadri  2019 - 2020    rabi          Rice     11.271429
#
# ...

# %%
df.isnull().sum()
# Out:
# S.No                         0
# District                     0
# Year                         0
# Season                       0
# Crop                         0
# Rainfall(mm)                 0
# Minimum Temparature(C)     260
# Maximum Temperature (C)    260
# Ph                           0
# N(Kg/Hectar)                 0
# P(Kg/Hectar)                 0
# K(Kg/Hectar)                 0
# Zn(ppm)                      0
# Fe(ppm)                      0
# Cu(ppm)                      0
# Mn(ppm)                      0
# Irrigation(MBGL)           141
# Yield (Bales/Hectare)       30
# dtype: int64

# %%
df.columns
# Out:
# Index(['S.No', 'District', 'Year', 'Season', 'Crop', 'Rainfall(mm)',
#        'Minimum Temparature(C)', 'Maximum Temperature (C)', 'Ph',
#        'N(Kg/Hectar)', 'P(Kg/Hectar)', 'K(Kg/Hectar)', 'Zn(ppm)', 'Fe(ppm)',
#        'Cu(ppm)', 'Mn(ppm)', 'Irrigation(MBGL)', 'Yield (Bales/Hectare)'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1136, step=1)

# %%
df.dropna(subset=['Yield (Bales/Hectare)'],inplace=True)
df.isnull().sum()
# Out:
# S.No                         0
# District                     0
# Year                         0
# Season                       0
# Crop                         0
# Rainfall(mm)                 0
# Minimum Temparature(C)     249
# Maximum Temperature (C)    249
# Ph                           0
# N(Kg/Hectar)                 0
# P(Kg/Hectar)                 0
# K(Kg/Hectar)                 0
# Zn(ppm)                      0
# Fe(ppm)                      0
# Cu(ppm)                      0
# Mn(ppm)                      0
# Irrigation(MBGL)           140
# Yield (Bales/Hectare)        0
# dtype: int64

# %%
df['District'][df['District']=='Adilabad']
e=df[df['District']=='Adilabad']
e
# Out:
#      S.No  District         Year  Season               Crop  Rainfall(mm)  \
# 0       1  Adilabad  2014 - 2015  Kharif       cotton(lint)    156.040000
# 1       2  Adilabad  2015 - 2016  Kharif       cotton(lint)    165.740000
# 2       3  Adilabad  2016 - 2017  Kharif       cotton(lint)    240.520000
# 3       4  Adilabad  2017 - 2018  Kharif       cotton(lint)    180.180000
# 4       5  Adilabad  2018 - 2019  Kharif       cotton(lint)    256.060000
# 5       6  Adilabad  2019 - 2020  Kharif       cotton(lint)    204.620000
# 142   143  Adilabad  2014 - 2015  Kharif              Maize    156.040000
# 143   144  Adilabad  2015 - 2016  Kharif              Maize    165.740000
# 144   145  Adilabad  2016 - 2017  Kharif              Maize    240.520000
# 145   146  Adilabad  2017 - 2018  Kharif              Maize    180.180000
# 146   147  Adilabad  2018 - 2019  Kharif              Maize    256.060000
# 147   148  Adilabad  2019 - 2020  Kharif              Maize    204.620000
# ...

# %%
a=df.groupby(['District', 'Season',])[['Minimum Temparature(C)']].mean()
a
# Out:
#                        Minimum Temparature(C)
# District       Season
# Adilabad       Kharif               25.380000
#                rabi                 22.300000
# Bhadradri      Kharif               25.800000
#                rabi                 22.033333
# Jagitial       Kharif               24.600000
# ...                                       ...
# Warangal       rabi                 23.660000
# Warangal urban Kharif               25.666667
#                rabi                 19.566667
# Yadadri        Kharif               24.866667
#                rabi                 20.166667
#
# [64 rows x 1 columns]

# %%
df["District"].unique()
# Out:
# array(['Adilabad', 'Bhadradri', 'Jagitial', 'Jangoan', 'Jayashankar',
#        'Jogulamba', 'Kamareddy', 'Karimnagar', 'Khammam',
#        'Komaram bheem asifabad', 'Mahabubabad', 'Mahbubnagar',
#        'Mancherial', 'Medak', 'Medchal', 'Mulugu', 'Nagarkurnool',
#        'Nalgonda', 'Narayanapet', 'Nirmal', 'Nizamabad', 'Peddapalli',
#        'Rajanna', 'Rangareddy', 'Sangareddy', 'Siddipet', 'Suryapet',
#        'Vikarabad', 'Wanaparthy', 'Warangal', 'Warangal urban', 'Yadadri'],
#       dtype=object)

# %%
#a=df.groupby(['District','Season'])[['Minimum Temparature(C)']].mean()
a
df['Minimum Temparature(C)']=df.groupby(['District', 'Season',])[['Minimum Temparature(C)']].apply(lambda x: x.fillna(x.mean()))
df
# Out:
#       S.No        District         Year  Season          Crop  Rainfall(mm)  \
# 0        1        Adilabad  2014 - 2015  Kharif  cotton(lint)    156.040000
# 1        2        Adilabad  2015 - 2016  Kharif  cotton(lint)    165.740000
# 2        3        Adilabad  2016 - 2017  Kharif  cotton(lint)    240.520000
# 3        4        Adilabad  2017 - 2018  Kharif  cotton(lint)    180.180000
# 4        5        Adilabad  2018 - 2019  Kharif  cotton(lint)    256.060000
# ...    ...             ...          ...     ...           ...           ...
# 1131  1132  Warangal urban  2019 - 2020    rabi          Rice     15.042900
# 1132  1133         Yadadri  2016 - 2017    rabi          Rice      5.171429
# 1133  1134         Yadadri  2017 - 2018    rabi          Rice     11.285714
# 1134  1135         Yadadri  2018 - 2019    rabi          Rice      6.571429
# 1135  1136         Yadadri  2019 - 2020    rabi          Rice     11.271429
#
# ...

# %%
a=df[['District','Season','Crop','Minimum Temparature(C)']][df['District']=='Adilabad']
a
# Out:
#      District  Season               Crop  Minimum Temparature(C)
# 0    Adilabad  Kharif       cotton(lint)                   29.10
# 1    Adilabad  Kharif       cotton(lint)                   26.10
# 2    Adilabad  Kharif       cotton(lint)                   27.30
# 3    Adilabad  Kharif       cotton(lint)                   27.60
# 4    Adilabad  Kharif       cotton(lint)                   25.38
# 5    Adilabad  Kharif       cotton(lint)                   16.80
# 142  Adilabad  Kharif              Maize                   29.10
# 143  Adilabad  Kharif              Maize                   26.10
# 144  Adilabad  Kharif              Maize                   27.30
# 145  Adilabad  Kharif              Maize                   27.60
# 146  Adilabad  Kharif              Maize                   25.38
# 147  Adilabad  Kharif              Maize                   16.80
# 284  Adilabad  Kharif  Moong(Green Gram)                   29.10
# ...

# %%
a=df.groupby(['District', 'Season',])[['Maximum Temperature (C)']].mean()
a
# Out:
#                        Maximum Temperature (C)
# District       Season
# Adilabad       Kharif                39.940000
#                rabi                  42.220000
# Bhadradri      Kharif                40.033333
#                rabi                  41.700000
# Jagitial       Kharif                40.266667
# ...                                        ...
# Warangal       rabi                  41.920000
# Warangal urban Kharif                39.700000
#                rabi                  40.866667
# Yadadri        Kharif                39.400000
#                rabi                  40.700000
#
# [64 rows x 1 columns]

# %%
df['Maximum Temperature (C)']=df.groupby(['District', 'Season',])[['Maximum Temperature (C)']].apply(lambda x: x.fillna(x.mean()))
df
# Out:
#       S.No        District         Year  Season          Crop  Rainfall(mm)  \
# 0        1        Adilabad  2014 - 2015  Kharif  cotton(lint)    156.040000
# 1        2        Adilabad  2015 - 2016  Kharif  cotton(lint)    165.740000
# 2        3        Adilabad  2016 - 2017  Kharif  cotton(lint)    240.520000
# 3        4        Adilabad  2017 - 2018  Kharif  cotton(lint)    180.180000
# 4        5        Adilabad  2018 - 2019  Kharif  cotton(lint)    256.060000
# ...    ...             ...          ...     ...           ...           ...
# 1131  1132  Warangal urban  2019 - 2020    rabi          Rice     15.042900
# 1132  1133         Yadadri  2016 - 2017    rabi          Rice      5.171429
# 1133  1134         Yadadri  2017 - 2018    rabi          Rice     11.285714
# 1134  1135         Yadadri  2018 - 2019    rabi          Rice      6.571429
# 1135  1136         Yadadri  2019 - 2020    rabi          Rice     11.271429
#
# ...

# %%
df.isnull().sum()
# Out:
# S.No                         0
# District                     0
# Year                         0
# Season                       0
# Crop                         0
# Rainfall(mm)                 0
# Minimum Temparature(C)       0
# Maximum Temperature (C)      0
# Ph                           0
# N(Kg/Hectar)                 0
# P(Kg/Hectar)                 0
# K(Kg/Hectar)                 0
# Zn(ppm)                      0
# Fe(ppm)                      0
# Cu(ppm)                      0
# Mn(ppm)                      0
# Irrigation(MBGL)           140
# Yield (Bales/Hectare)        0
# dtype: int64

# %%
f=df[['District','Season','Irrigation(MBGL)']][df['District']=='Adilabad']
f
# Out:
#      District  Season  Irrigation(MBGL)
# 0    Adilabad  Kharif              0.00
# 1    Adilabad  Kharif               NaN
# 2    Adilabad  Kharif             14.70
# 3    Adilabad  Kharif             13.95
# 4    Adilabad  Kharif             14.83
# 5    Adilabad  Kharif             14.18
# 142  Adilabad  Kharif               NaN
# 143  Adilabad  Kharif               NaN
# 144  Adilabad  Kharif             14.70
# 145  Adilabad  Kharif             13.95
# 146  Adilabad  Kharif             14.83
# 147  Adilabad  Kharif             14.18
# 284  Adilabad  Kharif               NaN
# 285  Adilabad  Kharif               NaN
# 286  Adilabad  Kharif             14.70
# 287  Adilabad  Kharif             13.95
# 288  Adilabad  Kharif             14.83
# 289  Adilabad  Kharif             14.18
# 426  Adilabad  Kharif               NaN
# 427  Adilabad  Kharif               NaN
# 428  Adilabad  Kharif             14.70
# 429  Adilabad  Kharif             13.95
# ...

# %%
df['Irrigation(MBGL)']=df.groupby(['District', 'Season',])[['Irrigation(MBGL)']].apply(lambda x: x.fillna(x.mean()))
df
df.isnull().sum()
# Out:
# S.No                       0
# District                   0
# Year                       0
# Season                     0
# Crop                       0
# Rainfall(mm)               0
# Minimum Temparature(C)     0
# Maximum Temperature (C)    0
# Ph                         0
# N(Kg/Hectar)               0
# P(Kg/Hectar)               0
# K(Kg/Hectar)               0
# Zn(ppm)                    0
# Fe(ppm)                    0
# Cu(ppm)                    0
# Mn(ppm)                    0
# Irrigation(MBGL)           0
# Yield (Bales/Hectare)      0
# dtype: int64

# %%
df.head(6)
# Out:
#    S.No  District         Year  Season          Crop  Rainfall(mm)  \
# 0     1  Adilabad  2014 - 2015  Kharif  cotton(lint)        156.04
# 1     2  Adilabad  2015 - 2016  Kharif  cotton(lint)        165.74
# 2     3  Adilabad  2016 - 2017  Kharif  cotton(lint)        240.52
# 3     4  Adilabad  2017 - 2018  Kharif  cotton(lint)        180.18
# 4     5  Adilabad  2018 - 2019  Kharif  cotton(lint)        256.06
# 5     6  Adilabad  2019 - 2020  Kharif  cotton(lint)        204.62
#
#    Minimum Temparature(C)  Maximum Temperature (C)    Ph  N(Kg/Hectar)  \
# 0                   29.10                    40.50  7.55         180.0
# 1                   26.10                    37.60  7.55         180.0
# 2                   27.30                    38.30  7.55         180.0
# 3                   27.60                    37.40  7.55         180.0
# 4                   25.38                    39.94  7.55         180.0
# ...

# %%
df.dtypes
# Out:
# S.No                         int64
# District                    object
# Year                        object
# Season                      object
# Crop                        object
# Rainfall(mm)               float64
# Minimum Temparature(C)     float64
# Maximum Temperature (C)    float64
# Ph                         float64
# N(Kg/Hectar)               float64
# P(Kg/Hectar)               float64
# K(Kg/Hectar)               float64
# Zn(ppm)                    float64
# Fe(ppm)                    float64
# Cu(ppm)                    float64
# Mn(ppm)                    float64
# Irrigation(MBGL)           float64
# Yield (Bales/Hectare)      float64
# dtype: object

# %%
df[['Rainfall(mm)','Minimum Temparature(C)','Maximum Temperature (C)']] = df[['Rainfall(mm)','Minimum Temparature(C)','Maximum Temperature (C)']].round(2)
df.head()
# Out:
#    S.No  District         Year  Season          Crop  Rainfall(mm)  \
# 0     1  Adilabad  2014 - 2015  Kharif  cotton(lint)        156.04
# 1     2  Adilabad  2015 - 2016  Kharif  cotton(lint)        165.74
# 2     3  Adilabad  2016 - 2017  Kharif  cotton(lint)        240.52
# 3     4  Adilabad  2017 - 2018  Kharif  cotton(lint)        180.18
# 4     5  Adilabad  2018 - 2019  Kharif  cotton(lint)        256.06
#
#    Minimum Temparature(C)  Maximum Temperature (C)    Ph  N(Kg/Hectar)  \
# 0                   29.10                    40.50  7.55         180.0
# 1                   26.10                    37.60  7.55         180.0
# 2                   27.30                    38.30  7.55         180.0
# 3                   27.60                    37.40  7.55         180.0
# 4                   25.38                    39.94  7.55         180.0
#
#    P(Kg/Hectar)  K(Kg/Hectar)  Zn(ppm)  Fe(ppm)  Cu(ppm)  Mn(ppm)  \
# ...

# %%
df.corr()
# Out:
#                              S.No  Rainfall(mm)  Minimum Temparature(C)  \
# S.No                     1.000000     -0.781745               -0.178656
# Rainfall(mm)            -0.781745      1.000000                0.205096
# Minimum Temparature(C)  -0.178656      0.205096                1.000000
# Maximum Temperature (C)  0.027022      0.027052                0.807018
# Ph                      -0.023401     -0.041136                0.042860
# N(Kg/Hectar)            -0.018933      0.065339               -0.048304
# P(Kg/Hectar)             0.019371     -0.013064               -0.052101
# K(Kg/Hectar)             0.025665      0.042233               -0.015022
# Zn(ppm)                  0.016281     -0.041969               -0.057308
# Fe(ppm)                 -0.022431      0.009048                0.045742
# Cu(ppm)                  0.012768      0.029413               -0.092698
# Mn(ppm)                 -0.037648      0.079990                0.028238
# ...

# %%
import matplotlib.pyplot as plt
df.boxplot(figsize=(50,50))
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               S.No  Rainfall(mm)  Minimum Temparature(C)  \
# count  1106.000000   1106.000000             1106.000000
# mean    561.777577     88.658626               23.900678
# std     328.132372     85.624276               13.489642
# min       1.000000      0.840000                5.000000
# 25%     277.250000     10.670000               19.800000
# 50%     556.500000     72.820000               24.900000
# 75%     839.750000    160.240000               27.600000
# max    1136.000000    273.020000              226.160000
#
#        Maximum Temperature (C)           Ph  N(Kg/Hectar)  P(Kg/Hectar)  \
# count              1106.000000  1106.000000   1106.000000   1106.000000
# mean                 41.028318     7.257107    219.856239     34.356438
# std                  11.724974     0.722821     68.374342     13.701101
# min                  33.100000     5.300000     97.000000     15.600000
# 25%                  37.300000     7.300000    170.700000     23.700000
# ...

# %%
import matplotlib.pyplot as plt
c=1
for i in df.columns:
    if(df[i].dtype!="object"):
        print(i)
        plt.boxplot(df[i])
        plt.show()
# Out:
# S.No
# Rainfall(mm)
# Minimum Temparature(C)
# Maximum Temperature (C)
# Ph
# N(Kg/Hectar)
# P(Kg/Hectar)
# K(Kg/Hectar)
# Zn(ppm)
# Fe(ppm)
# Cu(ppm)
# Mn(ppm)
# Irrigation(MBGL)
# Yield (Bales/Hectare)

# %%
import numpy as np

for i in df.columns:
    if(df[i].dtype!="object"):
        q1=np.percentile(df[i],25)
        q3=np.percentile(df[i],75)
        iqr=q3-q1
        ll=q1-1.5*iqr
        ul=q3+1.5*iqr
        print(df.loc[(df[i]<ll) | (df[i]>ul),i])
# Out:
# Series([], Name: S.No, dtype: int64)
# Series([], Name: Rainfall(mm), dtype: float64)
# 44      226.16
# 186     226.16
# 328     226.16
# 470     226.16
# 573       5.00
# 613       6.60
# 655       7.70
# 715       5.00
# 755       6.60
# 797       7.70
# 857       5.00
# 897       6.60
# 939       7.70
# 999       5.00
# 1039      6.60
# 1081      7.70
# Name: Minimum Temparature(C), dtype: float64
# 44     226.16
# 186    226.16
# 328    226.16
# 470    226.16
# Name: Maximum Temperature (C), dtype: float64
# 6       5.31
# 7       5.31
# 8       5.31
# 9       5.31
# 22      8.20
#         ...
# 1131    5.50
# 1132    6.54
# 1133    6.54
# 1134    6.54
# 1135    6.54
# Name: Ph, Length: 186, dtype: float64
# Series([], Name: N(Kg/Hectar), dtype: float64)
# 94      80.77
# 95      80.77
# 96      80.77
# 97      80.77
# 236     80.77
# 237     80.77
# 238     80.77
# 239     80.77
# 378     80.77
# 379     80.77
# 380     80.77
# 381     80.77
# 520     80.77
# 521     80.77
# ...

# %%
df.to_excel('pro.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df.to_excel('pro.xlsx')
#
# NameError: name 'df' is not defined
